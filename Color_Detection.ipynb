# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
# %matplotlib inline
import numpy as np

# %%
im = cv2.imread('parrot.jpg')
plt.imshow(im[:,:,::-1])

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(20, 3))
fig.suptitle('Horizontally stacked subplots')
ax1.imshow(im[:,:,2],cmap='gray')
ax2.imshow(im[:,:,1],cmap='gray')
ax3.imshow(im[:,:,0],cmap='gray')
ax4.imshow(im[:,:,::-1])

ax1.title.set_text('Only Red')
ax2.title.set_text('Only Green')
ax3.title.set_text('Only Blue')
ax4.title.set_text('BGR')

# %%
fig = plt.figure(figsize=(10,7))
fig.suptitle('Horizontally stacked subplots')
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
ax1.imshow(im[:,:,2],cmap='gray')
ax2.imshow(im[:,:,1],cmap='gray')
ax3.imshow(im[:,:,0],cmap='gray')
ax4.imshow(im[:,:,::-1])

ax1.title.set_text('Only Red')
ax2.title.set_text('Only Green')
ax3.title.set_text('Only Blue')
ax4.title.set_text('BGR')

# %%
# show image in new windows GUI to find BGR Code
# %matplotlib qt
a = im.copy()
plt.imshow(a[:,:,::-1])
plt.show()

# %%
# %matplotlib inline
tol = 35
color_avg = np.array([3,155,60])
color_min = np.array([1,140,50])
color_max = np.array([5,190,70])

mask = cv2.inRange(a,color-tol, color+tol)
mask_inv = ~mask
# mask = cv2.inRange(a,color_min, color_max)
amask = cv2.bitwise_and(a,a,mask=mask_inv)
notmask = cv2.bitwise_not(a,dst=a,mask=mask_inv)
plt.title('mask')
plt.imshow(mask,cmap='gray')
plt.show()
plt.title('mask_inv')
plt.imshow(mask_inv,cmap='gray')
plt.show()
plt.title('amask')
plt.imshow(amask[:,:,::-1])
plt.show()
plt.title('notmask')
plt.imshow(notmask[:,:,::-1])
plt.show();

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(30, 5))
fig.suptitle('Horizontally stacked subplots')
ax1.imshow(mask,cmap='gray')
ax2.imshow(mask_inv,cmap='gray')
ax3.imshow(amask[:,:,::-1])
ax4.imshow(im[:,:,::-1])

ax1.title.set_text('mask')
ax2.title.set_text('mask_inv')
ax3.title.set_text('amask')
ax4.title.set_text('BGR')

# %%
# %matplotlib inline
bg = cv2.imread('city.jpg')
bg = cv2.resize(bg,dsize=im.shape[::-1][1:])
bg_mask = cv2.bitwise_and(bg,bg,mask=mask)
plt.imshow(bg_mask[:,:,::-1])

# %%
parrot_in_city = cv2.bitwise_or(amask,bg_mask)
plt.imshow(parrot_in_city[:,:,::-1])
